# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sbn

# %% [markdown]
# ### Import CSV file as DataFrame

# %%
df = pd.read_csv('tesla.csv')
df
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     29-06-2010   19.000000   25.000000   17.540001   23.889999   23.889999
# 1     30-06-2010   25.790001   30.420000   23.299999   23.830000   23.830000
# 2     01-07-2010   25.000000   25.920000   20.270000   21.959999   21.959999
# 3     02-07-2010   23.000000   23.100000   18.709999   19.200001   19.200001
# 4     06-07-2010   20.000000   20.000000   15.830000   16.110001   16.110001
# ...          ...         ...         ...         ...         ...         ...
# 2188  11-03-2019  283.519989  291.279999  280.500000  290.920013  290.920013
# 2189  12-03-2019  286.489990  288.070007  281.059998  283.359985  283.359985
# 2190  13-03-2019  283.899994  291.989990  282.700012  288.959991  288.959991
# 2191  14-03-2019  292.450012  295.390015  288.290009  289.959991  289.959991
# 2192  15-03-2019  283.510010  283.723999  274.399994  275.429993  275.429993
#
#         Volume
# 0     18766300
# ...

# %%
df.shape
# Out:
# (2193, 7)

# %% [markdown]
# ### Preview top 5 rows of df

# %%
df.head()
# Out:
#          Date       Open   High        Low      Close  Adj Close    Volume
# 0  29-06-2010  19.000000  25.00  17.540001  23.889999  23.889999  18766300
# 1  30-06-2010  25.790001  30.42  23.299999  23.830000  23.830000  17187100
# 2  01-07-2010  25.000000  25.92  20.270000  21.959999  21.959999   8218800
# 3  02-07-2010  23.000000  23.10  18.709999  19.200001  19.200001   5139800
# 4  06-07-2010  20.000000  20.00  15.830000  16.110001  16.110001   6866900

# %% [markdown]
# ### Number of Null values in each row

# %%
df.isnull().sum() #There are no null values in the given dataframe
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %% [markdown]
# ### Basic info of df

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2193 entries, 0 to 2192
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       2193 non-null   object
#  1   Open       2193 non-null   float64
#  2   High       2193 non-null   float64
#  3   Low        2193 non-null   float64
#  4   Close      2193 non-null   float64
#  5   Adj Close  2193 non-null   float64
#  6   Volume     2193 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 120.1+ KB

# %% [markdown]
# ### Statistical info of df

# %%
df.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  2193.000000  2193.000000  2193.000000  2193.000000  2193.000000
# mean    175.652882   178.710262   172.412075   175.648555   175.648555
# std     115.580903   117.370092   113.654794   115.580771   115.580771
# min      16.139999    16.629999    14.980000    15.800000    15.800000
# 25%      33.110001    33.910000    32.459999    33.160000    33.160000
# 50%     204.990005   208.160004   201.669998   204.990005   204.990005
# 75%     262.000000   265.329987   256.209991   261.739990   261.739990
# max     386.690002   389.609985   379.350006   385.000000   385.000000
#
#              Volume
# count  2.193000e+03
# mean   5.077449e+06
# std    4.545398e+06
# min    1.185000e+05
# 25%    1.577800e+06
# 50%    4.171700e+06
# 75%    6.885600e+06
# max    3.716390e+07

# %%
df.corr()
# Out:
#                Open      High       Low     Close  Adj Close    Volume
# Open       1.000000  0.999578  0.999566  0.999054   0.999054  0.457938
# High       0.999578  1.000000  0.999490  0.999631   0.999631  0.466999
# Low        0.999566  0.999490  1.000000  0.999580   0.999580  0.448387
# Close      0.999054  0.999631  0.999580  1.000000   1.000000  0.458157
# Adj Close  0.999054  0.999631  0.999580  1.000000   1.000000  0.458157
# Volume     0.457938  0.466999  0.448387  0.458157   0.458157  1.000000

# %% [markdown]
# Plotting the heatmap for correlation

# %%
Correlation = sbn.heatmap(df.corr(),annot=True) #variables except 'volume' are highly correlated to each other.

# %%
pd.plotting.scatter_matrix(df,figsize=(15,6))
plt.show()

# %% [markdown]
# There is Linear variation among variables, but variable name 'Volume' is non uniformly scattered w. r. t. other variables

# %%
from matplotlib import pylab

# %% [markdown]
# Setting Date as an Index

# %%
df_new =df.set_index('Date')
df_new
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 29-06-2010   19.000000   25.000000   17.540001   23.889999   23.889999
# 30-06-2010   25.790001   30.420000   23.299999   23.830000   23.830000
# 01-07-2010   25.000000   25.920000   20.270000   21.959999   21.959999
# 02-07-2010   23.000000   23.100000   18.709999   19.200001   19.200001
# 06-07-2010   20.000000   20.000000   15.830000   16.110001   16.110001
# ...                ...         ...         ...         ...         ...
# 11-03-2019  283.519989  291.279999  280.500000  290.920013  290.920013
# 12-03-2019  286.489990  288.070007  281.059998  283.359985  283.359985
# 13-03-2019  283.899994  291.989990  282.700012  288.959991  288.959991
# 14-03-2019  292.450012  295.390015  288.290009  289.959991  289.959991
# 15-03-2019  283.510010  283.723999  274.399994  275.429993  275.429993
#
#               Volume
# Date
# 29-06-2010  18766300
# 30-06-2010  17187100
# 01-07-2010   8218800
# ...

# %%
df_new.axes
# Out:
# [Index(['29-06-2010', '30-06-2010', '01-07-2010', '02-07-2010', '06-07-2010',
#         '07-07-2010', '08-07-2010', '09-07-2010', '12-07-2010', '13-07-2010',
#         ...
#         '04-03-2019', '05-03-2019', '06-03-2019', '07-03-2019', '08-03-2019',
#         '11-03-2019', '12-03-2019', '13-03-2019', '14-03-2019', '15-03-2019'],
#        dtype='object', name='Date', length=2193),
#  Index(['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')]

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2193 entries, 29-06-2010 to 15-03-2019
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       2193 non-null   float64
#  1   High       2193 non-null   float64
#  2   Low        2193 non-null   float64
#  3   Close      2193 non-null   float64
#  4   Adj Close  2193 non-null   float64
#  5   Volume     2193 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 119.9+ KB

# %%
df_new['Open'].plot(label='Open',figsize=(15,7))
df_new['High'].plot(label='High')
df_new['Low'].plot(label='High')
df_new['Close'].plot(label='High')
df_new['Adj Close'].plot(label='High')
plt.legend()
plt.ylabel('Stock Price')
plt.title('Tesla Stock Price')
plt.show()

# %%
df_new['Volume'].plot(figsize=(18,8))
plt.title('Volume Traded')
# Out:
# Text(0.5, 1.0, 'Volume Traded')

# %% [markdown]
# Good number of stocks were traded between the year 2013 and 2014 and then the pattern remains same but hikes after year 2018.

# %% [markdown]
# # Barplot of columns w.r.t. Date

# %%
sbn.barplot(x=df['Date'],y=df['Open'])
plt.show()

# %%
sbn.barplot(x=df['Date'],y=df['High'])
plt.show()

# %%
sbn.barplot(x=df['Date'],y=df['Low'])
plt.show()

# %%
sbn.barplot(x=df['Date'],y=df['Close'])
plt.show()

# %%
sbn.barplot(x=df['Date'],y=df['Adj Close'])
plt.show()

# %%
sbn.barplot(x=df['Date'],y=df['Volume'])
plt.show()

# %% [markdown]
# # Linear Regression

# %%
df_new.columns
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %% [markdown]
# ### Feature variables

# %%
x = df_new.drop('Close',axis=1)
x
# Out:
#                   Open        High         Low   Adj Close    Volume
# Date
# 29-06-2010   19.000000   25.000000   17.540001   23.889999  18766300
# 30-06-2010   25.790001   30.420000   23.299999   23.830000  17187100
# 01-07-2010   25.000000   25.920000   20.270000   21.959999   8218800
# 02-07-2010   23.000000   23.100000   18.709999   19.200001   5139800
# 06-07-2010   20.000000   20.000000   15.830000   16.110001   6866900
# ...                ...         ...         ...         ...       ...
# 11-03-2019  283.519989  291.279999  280.500000  290.920013   7392300
# 12-03-2019  286.489990  288.070007  281.059998  283.359985   7504100
# 13-03-2019  283.899994  291.989990  282.700012  288.959991   6844700
# 14-03-2019  292.450012  295.390015  288.290009  289.959991   7074200
# 15-03-2019  283.510010  283.723999  274.399994  275.429993  14758243
#
# [2193 rows x 5 columns]

# %% [markdown]
# ### Target Variable

# %%
y = df_new['Close']
y
# Out:
# Date
# 29-06-2010     23.889999
# 30-06-2010     23.830000
# 01-07-2010     21.959999
# 02-07-2010     19.200001
# 06-07-2010     16.110001
#                  ...
# 11-03-2019    290.920013
# 12-03-2019    283.359985
# 13-03-2019    288.959991
# 14-03-2019    289.959991
# 15-03-2019    275.429993
# Name: Close, Length: 2193, dtype: float64

# %% [markdown]
# ### Feature scaling the data

# %%
from sklearn.preprocessing import StandardScaler
scaling = StandardScaler()
x = pd.DataFrame(data=scaling.fit_transform(x),columns=x.columns)
x
# Out:
#           Open      High       Low  Adj Close    Volume
# 0    -1.355662 -1.309919 -1.362964  -1.313308  3.012271
# 1    -1.296902 -1.263730 -1.312273  -1.313827  2.664764
# 2    -1.303738 -1.302079 -1.338938  -1.330010  0.691263
# 3    -1.321046 -1.326111 -1.352667  -1.353895  0.013721
# 4    -1.347008 -1.352529 -1.378013  -1.380636  0.393774
# ...        ...       ...       ...        ...       ...
# 2188  0.933473  0.959319  0.951236   0.997551  0.509390
# 2189  0.959176  0.931964  0.956165   0.932127  0.533992
# 2190  0.936762  0.965370  0.970598   0.980589  0.388889
# 2191  1.010753  0.994345  1.019793   0.989243  0.439391
# 2192  0.933387  0.894927  0.897553   0.863502  2.130287
#
# [2193 rows x 5 columns]

# %% [markdown]
# ### Relationship of each feature against the target (Close)

# %%
fig, axs = plt.subplots(ncols = 3, nrows = 2, figsize = (10, 10))
sbn.regplot(y = df['Close'], x = x['Open'], ax = axs[0, 0])
sbn.regplot(y = df['Close'], x = x['High'], ax = axs[0, 1])
sbn.regplot(y = df['Close'], x = x['Low'], ax = axs[0, 2])
sbn.regplot(y = df['Close'], x = x['Adj Close'], ax = axs[1, 0])
sbn.regplot(y = df['Close'], x = x['Volume'], ax = axs[1, 1])
plt.tight_layout()

# %% [markdown]
# ### Split the data

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=5)
print("Train features shape : ", x_train.shape)
print("Train target shape : ", y_train.shape)
print("Test features shape : ", x_test.shape)
print("Test target shape : ", y_test.shape)
# Out:
# Train features shape :  (1754, 5)
# Train target shape :  (1754,)
# Test features shape :  (439, 5)
# Test target shape :  (439,)

# %%
x_train
# Out:
#           Open      High       Low  Adj Close    Volume
# 1589  0.208448  0.238188  0.225717   0.241544  0.421126
# 539  -1.264536 -1.263985 -1.257709  -1.257836 -0.970092
# 1141  0.287891  0.266481  0.286441   0.268371 -0.106978
# 230  -1.270680 -1.269354 -1.270030  -1.264933 -0.383013
# 1942  1.274525  1.267134  1.290675   1.260890  0.228822
# ...        ...       ...       ...        ...       ...
# 740  -0.672002 -0.646055 -0.666310  -0.637003  1.239811
# 1032  0.534961  0.547792  0.556882   0.543826  0.068470
# 2121  1.482825  1.438426  1.470911   1.432411 -0.439390
# 1424  0.025937  0.083599  0.024535   0.101956  0.141505
# 1725  1.058782  1.106494  1.094686   1.148389  0.682131
#
# [1754 rows x 5 columns]

# %% [markdown]
# ### Train the model

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ### Interpret the model

# %%
print("Model intercept : ", model.intercept_, "\n")
print("Model coefficient: ", model.coef_, "\n")

for i in range(len(x.columns)):
    print(x.columns[i], ": ", model.coef_[i])
# Out:
# Model intercept :  175.6485545927953
#
# Model coefficient:  [ 6.05155528e-14 -1.08941379e-13 -3.72190592e-14  1.15554416e+02
#   1.99505451e-15]
#
# Open :  6.051555278612863e-14
# High :  -1.0894137890700857e-13
# Low :  -3.7219059195012465e-14
# Adj Close :  115.55441560515106
# Volume :  1.9950545056926553e-15

# %% [markdown]
# ### Model evaluation for training set

# %%
from sklearn.metrics import mean_squared_error,r2_score

# %%
y_train_predict = model.predict(x_train)
rmse = (np.sqrt(mean_squared_error(y_train,y_train_predict)))
r2 = r2_score(y_train,y_train_predict)

# %%
# Examine the first 10 predicted output from the model
output = pd.DataFrame(y_train[0:10])
output['Predicted'] = y_train_predict[0:10]
output['Difference'] = output['Predicted'] - output['Close']
print(output, "\n")

print("Model training performance:")
print("---------------------------")
print('RMSE is {}'.format(rmse))
print('R2 score is {}'.format(r2))
print("\n")
# Out:
#                  Close   Predicted    Difference
# Date
# 19-10-2016  203.559998  203.559998  2.842171e-14
# 16-08-2012   30.299999   30.299999  1.421085e-14
# 09-01-2015  206.660004  206.660004  2.842171e-14
# 26-05-2011   29.480000   29.480000 -1.065814e-14
# 16-03-2018  321.350006  321.350006  5.684342e-14
# 14-06-2017  380.660004  380.660004  5.684342e-14
# 24-02-2014  217.649994  217.649994  5.684342e-14
# 17-04-2018  287.690002  287.690002  5.684342e-14
# 12-09-2014  279.200012  279.200012  5.684342e-14
# 06-01-2012   26.910000   26.910000 -3.552714e-15
#
# Model training performance:
# ---------------------------
# RMSE is 4.222978275341594e-14
# R2 score is 1.0

# %% [markdown]
# ### Model evaluation for testing set

# %%
y_test_predict = model.predict(x_test)
rmse = (np.sqrt(mean_squared_error(y_test,y_test_predict)))
r2 = r2_score(y_test, y_test_predict)

# %%
# Examine the first 10 predicted output from the model
output = pd.DataFrame(y_test[0:10])
output['Predicted'] = y_test_predict[0:10]
output['Difference'] = output['Predicted'] - output['Close']
print(output, "\n")

print("Model testing performance:")
print("--------------------------")
print('RMSE is {}'.format(rmse))
print('R2 score is {}'.format(r2))
# Out:
#                  Close   Predicted    Difference
# Date
# 10-03-2011   24.010000   24.010000 -1.065814e-14
# 12-05-2014  184.669998  184.669998  2.842171e-14
# 22-04-2013   50.189999   50.189999 -1.421085e-14
# 23-09-2016  207.449997  207.449997  2.842171e-14
# 25-08-2015  220.029999  220.029999  2.842171e-14
# 15-12-2017  343.450012  343.450012  5.684342e-14
# 15-01-2014  164.130005  164.130005  2.842171e-14
# 29-10-2010   21.840000   21.840000 -2.486900e-14
# 11-11-2013  144.699997  144.699997  2.842171e-14
# 24-07-2014  223.539993  223.539993  2.842171e-14
#
# Model testing performance:
# --------------------------
# RMSE is 4.0612433905055845e-14
# R2 score is 1.0

# %% [markdown]
# ### Ploting actual and predicted values for the train and test dataset

# %%
fig = plt.subplots(1,2)
plt.subplot(1,2,1)
plt.title('Training Dataset')
plt.scatter(y_train, y_train_predict)
plt.plot(y_train,y_train_predict)
plt.xlabel('Actual')
plt.ylabel('Predicted')


plt.subplot(1,2,2)
plt.tight_layout()

plt.scatter(y_test, y_test_predict)
plt.plot(y_test,y_test_predict)
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.title('Testing Dataset')
plt.show()

# %% [markdown]
# This model gives good R2 score and less RSME loss
